# %%
import pandas as pd
import glob
files = glob.glob("data/*.csv")
df = []
for f in files:
    csv = pd.read_csv(f)
    df.append(csv)
df = pd.concat(df)

# %%
df.to_csv(r'GPSdata/data8_1.csv',index = None)

# %%
import pandas as pd
df = pd.read_csv(r'GPSdata/data8_1.csv')

# %%
df[(df['route_dir']==1)&(df['route_sn']==1)].to_csv(r'GPSdata/data_tmp.csv',index = None)

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import transbigdata as tbd
df['geometry'] = gpd.points_from_xy(df['lng'],df['lat'])

# %%
df['lat'].min()
# Out:
# 22.595546

# %%
df = gpd.GeoDataFrame(df)
df['flag'] = df['route_dir'].astype(str)+'_'+df['route_sn'].astype(str)
for i in df['flag'].drop_duplicates().sort_values():
    import seaborn as sns
    import matplotlib.pyplot as plt
    fig = plt.figure(1,(5,5))
    ax = plt.subplot(111)
    df[(df['flag']==i)].plot(ax = ax)
    plt.title(i)
    plt.xlim(113.990,114.000)
    plt.ylim(22.595,22.612)
    plt.show()

# %%
df[(df['route_dir']==2)&(df['route_sn']==12)].plot()

# %%
df[df['id']==8267].to_csv(r'GPSdata/data3_flag1.csv',index=None)

# %%
df.to_csv(r'GPSdata/data8_1.csv',index=None)
